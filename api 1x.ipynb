# %%
import requests

url = "https://1xbet.in/service-api/RestCore/api/external/v1/SliderTopGames/line"

querystring = {"tz":"3","lng":"en"}

payload = ""
headers = {
    "authority": "1xbet.in",
    "accept": "application/json, text/plain, */*",
    "accept-language": "en-US,en;q=0.9",
    "cookie": "lng=en; flaglng=en; is_rtl=1; tzo=3; fast_coupon=true; typeBetNames=full; auid=LVd25GM66lW/P8mZBQKyAg==; right_side=right; _ym_uid=1664805472974854955; _ym_d=1664805472; _ga=GA1.2.1835910388.1664805472; che_g=f1068ae4-433a-4f03-fb5f-4eada35dc49d; sh.session=9cb02c88-8816-4e1d-919d-60ae98f8fd47; pushfree_status=canceled; v3fr=1; SESSION=3aa7486d7897d02533079342a0572ced; visit=1-eeb44edf43ef173935f9b3dfbec3d7cd; completed_user_settings=true; _ym_isad=1; _gid=GA1.2.1189265794.1665249063; coefview=0; _ym_visorc=b; _glhf=1665291868; dnb=1; ggru=167",
    "referer": "https://1xbet.in/line/football",
    "sec-ch-ua": "^\^Chromium^^;v=^\^106^^, ^\^Google"
}

response = requests.request("GET", url, data=payload, headers=headers, params=querystring)

print(response.text)
# Out:
# [{"I":402648933,"SI":1,"SN":"Football","SE":"Football","LI":118587,"L":"UEFA Champions League","LE":"UEFA Champions League","O1I":3080,"O1":"Copenhagen","O1E":"Copenhagen","O1IMG":["3080.png"],"O1C":62,"O2I":1994,"O2":"Manchester City","O2E":"Manchester City","O2IMG":["57060f6368da70fbdfff37cb4b0280a5.png"],"O2C":39,"S":1665506700,"SS":true,"CI":147709859,"SGI":"6307c48df75a663f69965051","SInfo":{"CT1":[],"CT2":["Josep Guardiola"],"O1WLD":"0-5-1","O2WLD":"2-3-1"}},{"I":402648927,"SI":1,"SN":"Football","SE":"Football","LI":118587,"L":"UEFA Champions League","LE":"UEFA Champions League","O1I":2472,"O1":"Shakhtar Donetsk","O1E":"Shakhtar Donetsk","O1IMG":["2472.png"],"O1C":2,"O2I":2564,"O2":"Real Madrid","O2E":"Real Madrid","O2IMG":["65e3e972954419765c3ce21698edf6cb.png"],"O2C":78,"S":1665514800,"SS":true,"CI":147709858,"SGI":"6307c48df75a663f699652ff","SInfo":{"CT1":["Igor Jovicevic"],"CT2":["Carlo Ancelotti"],"O1WLD":"2-4-0","O2WLD":"4-2-0"}},{"I":402648936,"SI":1,"SN":"Football","SE"
# ...

# %%
import json

# %%
with open('bet1_10.json',encoding="utf8") as f:
    jsondata = json.load(f)

print(jsondata)
# Out:
# {'Error': '', 'ErrorCode': 0, 'Guid': '', 'Id': 0, 'Success': True, 'Value': [{'AE': [{'G': 10694, 'ME': [{'C': 1.78, 'G': 10694, 'P': 8.125, 'T': 2068}, {'C': 1.97, 'G': 10694, 'P': 8.125, 'T': 2069}, {'C': 1.85, 'G': 10694, 'P': 9.135, 'T': 2068}, {'C': 1.89, 'G': 10694, 'P': 9.135, 'T': 2069}]}, {'G': 10696, 'ME': [{'C': 1.87, 'G': 10696, 'P': 8, 'T': 2072}, {'C': 1.87, 'G': 10696, 'P': 8, 'T': 2073}, {'C': 1.87, 'G': 10696, 'P': 9, 'T': 2072}, {'C': 1.87, 'G': 10696, 'P': 9, 'T': 2073}]}], 'CHIMG': '3cd45dcefe61aa512f52d3937b897765.png', 'CID': 1, 'CN': 'Europe', 'CO': 53, 'COI': 223, 'E': [{'C': 1.39, 'G': 101, 'T': 401}, {'C': 3.13, 'G': 101, 'T': 402}, {'C': 1.95, 'G': 15, 'P': 117.5, 'T': 11}, {'C': 1.8, 'G': 15, 'P': 117.5, 'T': 12}, {'C': 1.85, 'G': 10694, 'P': 9.135, 'T': 2068}, {'C': 1.89, 'G': 10694, 'P': 9.135, 'T': 2069}, {'C': 1.87, 'G': 10696, 'P': 9, 'T': 2072}, {'C': 1.87, 'G': 10696, 'P': 9, 'T': 2073}, {'C': 1.4, 'G': 1, 'T': 1}, {'C': 3.14, 'G': 1, 'T': 3}, {'C'
# ...

# %%
jsondata['Value'][0].keys()
# Out:
# dict_keys(['AE', 'CHIMG', 'CID', 'CN', 'CO', 'COI', 'E', 'EC', 'HSI', 'I', 'KI', 'L', 'LE', 'LI', 'LR', 'MIO', 'MIS', 'MS', 'N', 'O1', 'O1C', 'O1E', 'O1I', 'O1IMG', 'O1IS', 'O1R', 'O2', 'O2C', 'O2E', 'O2I', 'O2IMG', 'O2IS', 'O2R', 'S', 'SE', 'SI', 'SN', 'SR', 'SmI', 'T', 'TN', 'TNS', 'HMH', 'R', 'SC', 'VA', 'VI'])

# %%
jsondata['Value'][2]['E']
# Out:
# [{'C': 5.55, 'G': 1, 'T': 1},
#  {'C': 25, 'G': 1, 'T': 2},
#  {'C': 1.11, 'G': 1, 'T': 3},
#  {'C': 5.38, 'G': 101, 'T': 401},
#  {'C': 1.1, 'G': 101, 'T': 402}]

# %%
team2
# Out:
# 'Celta'
